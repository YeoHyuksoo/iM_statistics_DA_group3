# %%
import pandas as pd
import folium
import json
import random
from IPython.display import IFrame

# %%
# 기존 데이터 및 파일 경로 설정
ori_file_path = '기존수소충전소.csv'
cand_file_path = '미래입지목록2.csv'
geojson_path = 'daegu_geojson_filtered.geojson'
map_file_path = 'daegu_map.html'  # 기존 파일 이름으로 덮어씌우기

# %%
# CSV 파일 읽기
ori_data = pd.read_csv(ori_file_path)
cand_data = pd.read_csv(cand_file_path)

ori_data = ori_data[:7]
ori_data
# Out:
#             수소충전소                          주소         위도          경도
# 0  대구 주행시험장 수소충전소  대구 달성군 구지면 국가산단서로 201 (창리)  35.646666  128.400978
# 1    하이넷 성서 수소충전소       대구 달서구 성서공단로 97 (갈산동)  35.843935  128.490143
# 2       대구관음수소충전소         대구 북구 관음로 127 (관음동)  35.942909  128.541579
# 3     대구혁신도시수소충전소         대구 동구 첨단로 120 (신서동)  35.886742  128.730106
# 4           합천주유소                       대구 서구  35.889664  128.545020
# 5        (주)담티주유소                      대구 수성구  35.854430  128.655624
# 6           조양주유소                       대구 중구  35.862650  128.603198

# %%
# 대구 지역 LPG 데이터 필터링
lpg_data = lpg_data[lpg_data['EMD_NM'].str.contains(r'\b(중구|서구|수성구)\b', na=False)]

lpg_data
# Out:
# C:\Users\82102\AppData\Local\Temp\ipykernel_19224\3531637865.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   lpg_data = lpg_data[lpg_data['EMD_NM'].str.contains(r'\b(중구|서구|수성구)\b', na=False)]
#     EMD_NM          CHARGE_NM                  ADDR           TEL  \
# 49   대구 서구             신대한LPG     대구광역시 서구 서대구로 121  053-566-2609
# 50   대구 서구           청구엘피지충전소     대구광역시 서구 국채보상로 92  053-552-1123
# 51   대구 서구           서대구IC충전소      대구광역시 서구 북비산로 48  053-566-0009
# 52   대구 서구           대기에너지(주)     대구광역시 서구 국채보상로 25  053-552-3000
# 53   대구 서구            화성가스(주)      대구광역시 서구 와룡로 346  053-565-0223
# 54  대구 수성구  대구개인택시운송사업조합제1충전소     대구광역시 수성구 수성로 286  053-763-0153
# 55  대구 수성구            (주)동일가스       대구광역시 수성구 청수로 1  053-762-8855
# 56  대구 수성구          대공원충전소(주)    대구광역시 수성구 동대구로 255  053-763-6022
# 57  대구 수성구           (주)삼원에너지  대구광역시 수성구 달구벌대로 2780  053-759-7700
# 58  대구 수성구           동대구가스충전소   대구광역시 수성구 국채보상로 913  053-755-0401
# 59  대구 수성구           상동엘피지충전소     대구광역시 수성구 신천동로 51  053-764-5050
# 60   대구 중구        SK엔크린 조양주유소   대구광역시 중구 달구벌대로 2194  053-427-5151
# 61   대구 중구   SK엔크린 KK직영 중앙주유소    대구광역시 중구 국채보상로 642  053-422-8010
# 62   대구 중구   SK엔크린 KK 유성셀프주유소        대구광역시 중구 동덕로 6  053-424-5775
# 63   대구 중구      SK엔크린 행운셀프주유소      대구광역시 중구 태평로 105  053-421-5145
#
#                 TYPE         위도          경도
# 49             자동차충전  35.870822  128.554039
# 50             자동차충전  35.868409  128.541218
# 51             자동차충전  35.878491  128.537390
# 52             자동차충전  35.868912  128.546366
# 53  용기+자동차+탱크+13kg용기  35.863429  128.537913
# 54             자동차충전  35.837735  128.611990
# 55             자동차충전  35.840290  128.636242
# 56             자동차충전  35.866661  128.627052
# 57             자동차충전  35.859923  128.627998
# 58             자동차충전  35.866301  128.638717
# 59             자동차충전  35.829693  128.608164
# 60               NaN  35.861386  128.604557
# 61               NaN  35.867947  128.612263
# 62               NaN  35.864727  128.603873
# 63               NaN  35.873341  128.608776

# %%
# 지도 생성 (대구 지역 중심)
m = folium.Map(location=[35.854082, 128.656673], zoom_start=13, tiles='OpenStreetMap')

# %%
# GeoJSON 데이터 로드
with open(geojson_path, 'r', encoding='utf-8') as f:
    daegu_geojson = json.load(f)

# %%
# 구별 색상 설정
districts = {feature['properties']['sggnm']: f"#{random.randint(0, 0xFFFFFF):06x}" for feature in daegu_geojson['features']}

# %%
# GeoJSON 데이터 지도에 추가 (구 경계 표시)
for feature in daegu_geojson['features']:
    gu_name = feature['properties']['sggnm']
    folium.GeoJson(
        feature,
        style_function=lambda x, gu_name=gu_name: {
            'fillColor': districts[gu_name],
            'color': 'black',
            'fillOpacity': 0.3,
            'weight': 1
        },
        tooltip=f"구역: {gu_name}"
    ).add_to(m)

# %% [markdown]
# ### LPG 충전소

# %%
# LPG 충전소 위치에 CircleMarker 및 반경 500미터 원 추가
for _, row in ori_data.iterrows():
    folium.CircleMarker(
        location=[row['위도'], row['경도']],
        radius=5,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        # tooltip=f"LPG: {row['CHARGE_NM']} ({row['ADDR']})",  # 툴팁 추가
    ).add_to(m)

    folium.Circle(
        location=[row['위도'], row['경도']],
        radius=300,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.1,
        # tooltip=f"LPG: {row['CHARGE_NM']} ({row['ADDR']})",  # 툴팁 추가
    ).add_to(m)

# %% [markdown]
# ## 주유소

# %%
import pandas as pd
import folium

# %%
oil_file_path = '주유소수성구서구중구.csv'

# %%
oil_data = pd.read_csv("주유소LPG/" + oil_file_path)

# %%
oil_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   사업구분         90 non-null     object
#  1   상호           90 non-null     object
#  2   영업소소재지(도로명)  90 non-null     object
#  3   영업소소재지(지번)   81 non-null     object
#  4   영업소전화번호      90 non-null     object
#  5   기준일          90 non-null     object
#  6   위도           90 non-null     float64
#  7   경도           90 non-null     float64
# dtypes: float64(2), object(6)
# memory usage: 5.8+ KB

# %%
cand_data = pd.read_csv("미래입지목록.csv")

# %%
# 지도에 표시하기
for _, row in cand_data.iterrows():
    # 원 마커 추가 (반경 500m 예시)
    if row['위도'] > 0:
        folium.CircleMarker(
            location=[row['위도'], row['경도']],
            radius=5,  # 원 마커의 크기
            color='red',  # 테두리 색상
            fill=True,
            fill_color='red',
            fill_opacity=0.8,  # 투명도
            # tooltip=f"주유소: {row['상호']}, {row['영업소소재지(도로명)']}",  # 툴팁 추가
        ).add_to(m)
    
        # 반경 500m 원 추가
        folium.Circle(
            location=[row['위도'], row['경도']],
            radius=300,  # 반경 500미터
            color='orange',  # 테두리 색상
            fill=True,
            fill_color='orange',
            fill_opacity=0.2,
            # tooltip=f"주유소: {row['상호']}, {row['영업소소재지(도로명)']}",  # 툴팁 추가
        ).add_to(m)

# %%
# 지도 저장 및 표시
map_file_path = 'daegu_map.html'
m.save(map_file_path)

# %% [markdown]
# ### 학교

# %%
sens_data = pd.read_csv("민감시설/민감시설통합.csv")

# %%
school_data = sens_data[sens_data['시설종류'] == '학교']

school_data
# Out:
#        구       시설명                    주소         위도          경도 시설종류
# 412  NaN  정화여자고등학교  대구광역시 수성구 범어동 산105-1  35.849408  128.641888   학교
# 413  NaN  대구욱수초등학교     대구광역시 수성구 신매동 602  35.831377  128.707701   학교
# 414  NaN  대구이현초등학교     대구광역시 서구 평리동 1500  35.873486  128.550400   학교
# 415  NaN    서대구중학교      대구광역시 서구 평리동 509  35.880310  128.556626   학교
# 416  NaN  대구서부초등학교    대구광역시 서구 비산동 405-1  35.873880  128.573714   학교
# ..   ...       ...                   ...        ...         ...  ...
# 531  NaN  대구명덕초등학교     대구광역시 중구 남산동 2113  35.857541  128.589027   학교
# 532  NaN  경북공업고등학교   대구광역시 중구 남산동 2380-5  35.858514  128.583501   학교
# 533  NaN  대구종로초등학교    대구광역시 중구 서문로1가 1-5  35.872497  128.589704   학교
# 534  NaN  경북여자고등학교    대구광역시 중구 남산동 714-2  35.858427  128.592200   학교
# 535  NaN     계성중학교    대구광역시 중구 대신동 277-1  35.867936  128.580250   학교
#
# [124 rows x 6 columns]

# %%
# 학교 위치에 대한 마커 추가
for _, row in school_data.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        icon=folium.Icon(color='green', icon='graduation-cap', prefix='fa'),
        popup=f"{row['시설명']} ({row['주소']})"
    ).add_to(m)

# %% [markdown]
# ### 어린이집,유치원

# %% [markdown]
# color argument of Icon should be one of: {'darkpurple', 'darkgreen', 'green', 'lightgray', 'red', 'lightred', 'black', 'pink', 'darkred', 'lightgreen', 'lightblue', 'orange', 'darkblue', 'gray', 'beige', 'purple', 'white', 'cadetblue', 'blue'}.

# %%
kinder_data = sens_data[sens_data['시설종류'] == '어린이집,유치원']

kinder_data
# Out:
#        구            시설명                     주소         위도          경도  \
# 536   서구      구립 분도어린이집   대구광역시 서구 달구벌대로365길 3  35.861052  128.563331
# 537   서구   구립 아이편한숲어린이집  대구광역시 서구 달구벌대로361길 41  35.863807  128.559617
# 538   서구         유라어린이집   대구광역시 서구 서대구로6길 31-2  35.861452  128.560984
# 539   서구        해오름어린이집      대구광역시 서구 통학로7길 19  35.863267  128.562218
# 540   서구    대구서부경찰서어린이집        대구광역시 서구 통학로 33  35.863305  128.563984
# ..   ...            ...                    ...        ...         ...
# 834  NaN  대구평리초등학교병설유치원  대구광역시 서구 국채보상로53길 6-5  35.872401  128.560712
# 835  NaN          동양유치원   대구광역시 서구 평리로78길 8-12  35.865490  128.565126
# 836  NaN          상지유치원        대구광역시 서구 달서로 33  35.865554  128.570026
# 837  NaN          세화유치원     대구광역시 서구 서대구로5길 56  35.860008  128.550490
# 838  NaN        창의나라유치원    대구광역시 서구 서대구로42길 53  35.877256  128.561113
#
#          시설종류
# 536  어린이집,유치원
# 537  어린이집,유치원
# 538  어린이집,유치원
# 539  어린이집,유치원
# 540  어린이집,유치원
# ..        ...
# 834  어린이집,유치원
# 835  어린이집,유치원
# 836  어린이집,유치원
# 837  어린이집,유치원
# 838  어린이집,유치원
#
# [303 rows x 6 columns]

# %%
# 유치원 위치에 졸업 모자 모양 아이콘 추가
for _, row in kinder_data.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        icon=folium.Icon(color='green', icon='children', prefix='fa'),
        popup=f"{row['시설명']} ({row['주소']})"
    ).add_to(m)

# %% [markdown]
# ## 의료기관

# %%
hosp_data = sens_data[sens_data['시설종류'] == '병원']

hosp_data
# Out:
#        구          시설명                                      주소         위도  \
# 839  NaN  계명대학교대구동산병원      대구광역시 중구 달성로 56, 계명대학교대구동산병원 (동산동)  35.868779
# 840  NaN        제이원병원          대구광역시 서구 국채보상로 232, 1~5층 (평리동)  35.870466
# 841  NaN         으뜸병원                 대구광역시 중구 국채보상로 536 (수동)  35.870051
# 842  NaN       누네안과병원  대구광역시 중구 달구벌대로 2179, 눈빌딩 1층~8층 (삼덕동2가)  35.863744
# 843  NaN       대한요양병원           대구광역시 중구 중앙대로 297, 3~7층 (남산동)  35.859908
# ..   ...          ...                                     ...        ...
# 949  NaN       노아한방병원           대구광역시 중구 국채보상로139길 41 (동인동1가)  35.871067
# 950  NaN     노아동인요양병원           대구광역시 중구 국채보상로139길 41 (동인동1가)  35.871067
# 951  NaN       노아요양병원           대구광역시 중구 국채보상로139길 41 (동인동1가)  35.871067
# 952  NaN       백초한방병원       대구광역시 수성구 명덕로 414, 10~12층 (수성동2가)  35.854111
# 953  NaN         더필병원                 대구광역시 서구 서대구로 194 (평리동)  35.875378
#
#              경도 시설종류
# 839  128.582670   병원
# 840  128.556562   병원
# 841  128.589351   병원
# 842  128.601924   병원
# 843  128.591581   병원
# ..          ...  ...
# 949  128.606178   병원
# 950  128.606178   병원
# 951  128.606178   병원
# 952  128.615416   병원
# 953  128.555275   병원
#
# [115 rows x 6 columns]

# %%
# 어린이집) 위치에 졸업 모자 모양 아이콘 추가
for _, row in hosp_data.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        icon=folium.Icon(color='blue', icon='medkit', prefix='fa'),
        popup=f"{row['시설명']} ({row['주소']})"
    ).add_to(m)

# %% [markdown]
# ## 공원

# %%
park_data = sens_data[sens_data['시설종류'] == '공원']

park_data
# Out:
#        구          시설명                   주소         위도          경도 시설종류
# 385  NaN       가르뱅이공원                  NaN  35.880373  128.524312   공원
# 386  NaN        감삼못공원                  NaN  35.858329  128.552501   공원
# 387  NaN         노변공원                  NaN  35.838823  128.698946   공원
# 388  NaN       대구체육공원                  NaN  35.828560  128.687238   공원
# 389  NaN        두건골공원                  NaN  35.858128  128.651691   공원
# 390  NaN         매호공원                  NaN  35.844972  128.703679   공원
# 391  NaN        무학산공원                  NaN  35.834051  128.634038   공원
# 392  NaN         범물공원                  NaN  35.818314  128.643157   공원
# 393  NaN         범어공원                  NaN  35.847319  128.632940   공원
# 394  NaN         상리공원                  NaN  35.862590  128.531141   공원
# 395  NaN         수성공원                  NaN  35.860571  128.614908   공원
# 396  NaN         신매공원                  NaN  35.832351  128.709037   공원
# 397  NaN        야시골공원                  NaN  35.863184  128.632465   공원
# 398  NaN        의료1공원                  NaN  35.833593  128.691350   공원
# 399  NaN        의료2공원                  NaN  35.836149  128.680537   공원
# 400  NaN         의료공원                  NaN  35.836544  128.693942   공원
# 401  NaN         이현공원                  NaN  35.872943  128.543963   공원
# 402  NaN         지산공원                  NaN  35.821093  128.637732   공원
# 403  NaN         평리공원                  NaN  35.872321  128.557918   공원
# 404  NaN         화랑공원                  NaN  35.871050  128.639626   공원
# 405   중구  2.28기념 중앙공원      대구광역시 중구 공평동 15  35.870303  128.597983   공원
# 406   중구     건들바위역사공원  대구광역시 중구 대봉동 733-17  35.857071  128.598268   공원
# 407   중구       경상감영공원      대구광역시 중구 포정동 21  35.872615  128.591788   공원
# 408   중구   국채보상운동기념공원    대구광역시 중구 동인동2가 42  35.868179  128.600571   공원
# 409   중구         달성공원   대구광역시 중구 달성동 294-1  35.873581  128.579178   공원
# 410   중구         수창공원     대구광역시 중구 수창동 174  35.876556  128.585281   공원
# 411   중구       제2수창공원      대구광역시 중구 수창동 64  35.875755  128.583298   공원

# %%
# 공) 위치에 졸업 모자 모양 아이콘 추가
for _, row in park_data.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        icon=folium.Icon(color='black', icon='square-parking', prefix='fa'),
        popup=f"{row['시설명']}"
    ).add_to(m)

# %%
# 지도 저장 및 표시
map_file_path = 'daegu_map.html'
m.save(map_file_path)

# %% [markdown]
# ## 지도 시각화

# %%
# 대구 지역 범위에 지도 초점 맞춤
bounds = [[daegu_data['lati'].min(), daegu_data['longi'].min()], [daegu_data['lati'].max(), daegu_data['longi'].max()]]
m.fit_bounds(bounds)

# %%
# 지도 저장 및 표시 (기존 파일 이름으로 덮어쓰기)
m.save(map_file_path)
IFrame(map_file_path, width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="daegu_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
